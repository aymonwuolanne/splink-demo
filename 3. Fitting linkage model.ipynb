# %% [markdown]
# # Setup

# %%
import duckdb
from splink import Linker, DuckDBAPI, SettingsCreator, block_on
import splink.comparison_library as cl
import splink.comparison_level_library as cll

# %%
con = duckdb.connect()

df_l = con.read_parquet("./perturbed_data_l.parquet")
df_r = con.read_parquet("./perturbed_data_r.parquet")

con.register('df_l', df_l)
con.register('df_r', df_r)

# %%
geography_comparison = cl.CustomComparison(
    comparison_levels=[
        cll.And(cll.NullLevel("address"), cll.NullLevel("sa4")),
        cll.ArrayIntersectLevel("address", 1),
        cll.ArrayIntersectLevel("sa4", 1),
        cll.ElseLevel(),
    ],
    output_column_name="geography",
)

dob_comparison = cl.CustomComparison(
    comparison_levels=[
        cll.NullLevel("dob"),
        cll.ExactMatchLevel("dob"),
        cll.LevenshteinLevel("cast(dob as string)", 1),
        cll.AbsoluteDateDifferenceLevel("dob", input_is_string=False, threshold=1, metric="month"),
        cll.AbsoluteDateDifferenceLevel("dob", input_is_string=False, threshold=1, metric="year"),
        cll.ElseLevel(),
    ],
    output_column_name="dob",
)

settings = SettingsCreator(
    link_type="link_and_dedupe",
    comparisons=[
        cl.JaroWinklerAtThresholds("fname", [0.9]),
        cl.JaroWinklerAtThresholds("sname", [0.9]),
        cl.ExactMatch("sex"),
        dob_comparison,
        geography_comparison,
    ],
    blocking_rules_to_generate_predictions=[
        block_on("fname", "sname"),
        block_on("dob"),
        block_on("address", arrays_to_explode=["address"]),
    ],
    retain_intermediate_calculation_columns=True,
    retain_matching_columns=True,
    probability_two_random_records_match=1/92700
)

linker = Linker(
    input_table_or_tables=['df_l', 'df_r'],
    input_table_aliases=['df_l', 'df_r'],
    settings=settings,
    db_api=DuckDBAPI(con),
)

linker.training.estimate_u_using_random_sampling(max_pairs=1e7)

ts1 = linker.training.estimate_parameters_using_expectation_maximisation(
    blocking_rule=block_on("dob"),
    estimate_without_term_frequencies=True,
)

ts2 = linker.training.estimate_parameters_using_expectation_maximisation(
    blocking_rule=block_on("fname", "substring(sname, 1, 2)"),
    estimate_without_term_frequencies=True,
)

ts3 = linker.training.estimate_parameters_using_expectation_maximisation(
    blocking_rule=block_on("fname", "address[1]"),
    estimate_without_term_frequencies=True,
)

ts4 = linker.training.estimate_parameters_using_expectation_maximisation(
    blocking_rule=block_on("sname", "sa4[1]"),
    estimate_without_term_frequencies=True,
)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - fname (no m values are trained).
#     - sname (no m values are trained).
#     - sex (no m values are trained).
#     - dob (no m values are trained).
#     - geography (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."dob" = r."dob"
#
# Parameter estimates will be made for the following comparison(s):
#     - fname
#     - sname
#     - sex
#     - geography
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - dob
#
# Iteration 1: Largest change in params was -0.349 in the m_probability of sname, level `Exact match on sname`
# Iteration 2: Largest change in params was 0.0594 in the m_probability of sname, level `All other comparisons`
# Iteration 3: Largest change in params was 0.00748 in the m_probability of sname, level `All other comparisons`
# Iteration 4: Largest change in params was 0.00257 in the m_probability of fname, level `All other comparisons`
# Iteration 5: Largest change in params was 0.000826 in the m_probability of fname, level `All other comparisons`
# Iteration 6: Largest change in params was 0.000262 in the m_probability of fname, level `All other comparisons`
# Iteration 7: Largest change in params was 8.2e-05 in the m_probability of fname, level `All other comparisons`
#
# EM converged after 7 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - dob (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."fname" = r."fname") AND (SUBSTRING(l.sname, 1, 2) = SUBSTRING(r.sname, 1, 2))
#
# Parameter estimates will be made for the following comparison(s):
#     - sex
#     - dob
#     - geography
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - fname
#     - sname
#
# Iteration 1: Largest change in params was -0.0761 in the m_probability of dob, level `Exact match on dob`
# Iteration 2: Largest change in params was -0.00483 in the m_probability of sex, level `All other comparisons`
# Iteration 3: Largest change in params was -0.0017 in the m_probability of sex, level `All other comparisons`
# Iteration 4: Largest change in params was 0.00118 in the m_probability of dob, level `Exact match on dob`
# Iteration 5: Largest change in params was 0.000826 in the m_probability of dob, level `Exact match on dob`
# Iteration 6: Largest change in params was 0.000541 in the m_probability of dob, level `Exact match on dob`
# Iteration 7: Largest change in params was -0.000346 in the m_probability of dob, level `All other comparisons`
# Iteration 8: Largest change in params was -0.000216 in the m_probability of dob, level `All other comparisons`
# Iteration 9: Largest change in params was -0.000133 in the m_probability of dob, level `All other comparisons`
# Iteration 10: Largest change in params was -8.11e-05 in the m_probability of dob, level `All other comparisons`
#
# EM converged after 10 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."fname" = r."fname") AND (l."address"[1] = r."address"[1])
#
# Parameter estimates will be made for the following comparison(s):
#     - sname
#     - sex
#     - dob
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - fname
#     - geography
#
# Iteration 1: Largest change in params was 0.824 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.0767 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.016 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.00613 in probability_two_random_records_match
# Iteration 5: Largest change in params was 0.00267 in probability_two_random_records_match
# Iteration 6: Largest change in params was 0.00176 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.00146 in the m_probability of dob, level `All other comparisons`
# Iteration 8: Largest change in params was 0.00125 in the m_probability of dob, level `All other comparisons`
# Iteration 9: Largest change in params was 0.00104 in the m_probability of dob, level `All other comparisons`
# Iteration 10: Largest change in params was 0.000824 in the m_probability of dob, level `All other comparisons`
# Iteration 11: Largest change in params was 0.000629 in the m_probability of dob, level `All other comparisons`
# Iteration 12: Largest change in params was 0.000466 in the m_probability of dob, level `All other comparisons`
# Iteration 13: Largest change in params was 0.000336 in the m_probability of dob, level `All other comparisons`
# Iteration 14: Largest change in params was 0.000239 in the m_probability of dob, level `All other comparisons`
# Iteration 15: Largest change in params was 0.000167 in the m_probability of dob, level `All other comparisons`
# Iteration 16: Largest change in params was 0.000116 in the m_probability of dob, level `All other comparisons`
# Iteration 17: Largest change in params was 8e-05 in the m_probability of dob, level `All other comparisons`
#
# EM converged after 17 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."sname" = r."sname") AND (l."sa4"[1] = r."sa4"[1])
#
# Parameter estimates will be made for the following comparison(s):
#     - fname
#     - sex
#     - dob
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - sname
#     - geography
#
# Iteration 1: Largest change in params was 0.0581 in the m_probability of dob, level `Exact match on dob`
# Iteration 2: Largest change in params was -0.0198 in the m_probability of dob, level `Exact match on dob`
# Iteration 3: Largest change in params was 0.019 in the m_probability of fname, level `All other comparisons`
# Iteration 4: Largest change in params was 0.00813 in the m_probability of fname, level `All other comparisons`
# Iteration 5: Largest change in params was 0.00194 in the m_probability of fname, level `All other comparisons`
# Iteration 6: Largest change in params was 0.000417 in the m_probability of fname, level `All other comparisons`
# Iteration 7: Largest change in params was 9.06e-05 in the m_probability of fname, level `All other comparisons`
#
# EM converged after 7 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
linker.visualisations.parameter_estimate_comparisons_chart()
# Out:
# alt.Chart(...)

# %%
linker.visualisations.match_weights_chart()
# Out:
# C:\Users\aymon\Documents\splink-demo\venv\Lib\site-packages\altair\vegalite\v6\api.py:4124: UserWarning: Automatically deduplicated selection parameter with identical configuration. If you want independent parameters, explicitly name them differently (e.g., name='param1', name='param2'). See https://github.com/vega/altair/issues/3891
#   return _tp.from_dict(dct, validate=validate)
# alt.VConcatChart(...)

# %%
linker.misc.save_model_to_json("./model.json", overwrite=True)
# Out:
# {'link_type': 'link_and_dedupe',
#  'probability_two_random_records_match': 1.0787486515641855e-05,
#  'retain_matching_columns': True,
#  'retain_intermediate_calculation_columns': True,
#  'additional_columns_to_retain': [],
#  'sql_dialect': 'duckdb',
#  'linker_uid': 'bpymq0oe',
#  'em_convergence': 0.0001,
#  'max_iterations': 25,
#  'bayes_factor_column_prefix': 'bf_',
#  'term_frequency_adjustment_column_prefix': 'tf_',
#  'comparison_vector_value_column_prefix': 'gamma_',
#  'unique_id_column_name': 'unique_id',
#  'source_dataset_column_name': 'source_dataset',
#  'blocking_rules_to_generate_predictions': [{'blocking_rule': '(l."fname" = r."fname") AND (l."sname" = r."sname")',
#    'sql_dialect': 'duckdb'},
#   {'blocking_rule': 'l."dob" = r."dob"', 'sql_dialect': 'duckdb'},
#   {'blocking_rule': 'l."address" = r."address"',
#    'sql_dialect': 'duckdb',
#    'arrays_to_explode': ['address']}],
#  'comparisons': [{'output_column_name': 'fname',
#    'comparison_levels': [{'sql_condition': '"fname_l" IS NULL OR "fname_r" IS NULL',
#      'label_for_charts': 'fname is NULL',
#      'fix_m_probability': False,
#      'fix_u_probability': False,
#      'is_null_level': True},
#     {'sql_condition': '"fname_l" = "fname_r"',
#      'label_for_charts': 'Exact match on fname',
#      'm_probability': 0.7394602733751733,
#      'u_probability': 0.008570576566360132,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'jaro_winkler_similarity("fname_l", "fname_r") >= 0.9',
#      'label_for_charts': 'Jaro-Winkler distance of fname >= 0.9',
#      'm_probability': 0.16708426580055236,
#      'u_probability': 0.0018245457376465043,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ELSE',
#      'label_for_charts': 'All other comparisons',
#      'm_probability': 0.09345546082427436,
#      'u_probability': 0.9896048776959934,
#      'fix_m_probability': False,
#      'fix_u_probability': False}],
#    'comparison_description': 'JaroWinklerAtThresholds'},
#   {'output_column_name': 'sname',
#    'comparison_levels': [{'sql_condition': '"sname_l" IS NULL OR "sname_r" IS NULL',
#      'label_for_charts': 'sname is NULL',
#      'fix_m_probability': False,
#      'fix_u_probability': False,
#      'is_null_level': True},
#     {'sql_condition': '"sname_l" = "sname_r"',
#      'label_for_charts': 'Exact match on sname',
#      'm_probability': 0.5457284217658275,
#      'u_probability': 0.0040626319108475325,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'jaro_winkler_similarity("sname_l", "sname_r") >= 0.9',
#      'label_for_charts': 'Jaro-Winkler distance of sname >= 0.9',
#      'm_probability': 0.12481009869406073,
#      'u_probability': 0.0010344267641430648,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ELSE',
#      'label_for_charts': 'All other comparisons',
#      'm_probability': 0.3294614795401119,
#      'u_probability': 0.9949029413250094,
#      'fix_m_probability': False,
#      'fix_u_probability': False}],
#    'comparison_description': 'JaroWinklerAtThresholds'},
#   {'output_column_name': 'sex',
#    'comparison_levels': [{'sql_condition': '"sex_l" IS NULL OR "sex_r" IS NULL',
#      'label_for_charts': 'sex is NULL',
#      'fix_m_probability': False,
#      'fix_u_probability': False,
#      'is_null_level': True},
#     {'sql_condition': '"sex_l" = "sex_r"',
#      'label_for_charts': 'Exact match on sex',
#      'm_probability': 0.9763806440520595,
#      'u_probability': 0.49988580596295074,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ELSE',
#      'label_for_charts': 'All other comparisons',
#      'm_probability': 0.02361935594794049,
#      'u_probability': 0.5001141940370493,
#      'fix_m_probability': False,
#      'fix_u_probability': False}],
#    'comparison_description': 'ExactMatch'},
#   {'output_column_name': 'dob',
#    'comparison_levels': [{'sql_condition': '"dob_l" IS NULL OR "dob_r" IS NULL',
#      'label_for_charts': 'dob is NULL',
#      'fix_m_probability': False,
#      'fix_u_probability': False,
#      'is_null_level': True},
#     {'sql_condition': '"dob_l" = "dob_r"',
#      'label_for_charts': 'Exact match on dob',
#      'm_probability': 0.8814237761111143,
#      'u_probability': 4.5966226919589605e-05,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'levenshtein(CAST(dob_l AS TEXT), CAST(dob_r AS TEXT)) <= 1',
#      'label_for_charts': 'Levenshtein distance of cast(dob as string) <= 1',
#      'm_probability': 0.042215957975160937,
#      'u_probability': 0.001177029929588576,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ABS(EPOCH("dob_l") - EPOCH("dob_r")) <= 2629800.0',
#      'label_for_charts': "Abs difference of 'dob <= 1 month'",
#      'm_probability': 0.030272717661690988,
#      'u_probability': 0.0019534068652716217,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ABS(EPOCH("dob_l") - EPOCH("dob_r")) <= 31557600.0',
#      'label_for_charts': "Abs difference of 'dob <= 1 year'",
#      'm_probability': 0.01855042653622173,
#      'u_probability': 0.02635169107329562,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ELSE',
#      'label_for_charts': 'All other comparisons',
#      'm_probability': 0.029223131835720124,
#      'u_probability': 0.9704719059049246,
#      'fix_m_probability': False,
#      'fix_u_probability': False}],
#    'comparison_description': 'CustomComparison'},
#   {'output_column_name': 'geography',
#    'comparison_levels': [{'sql_condition': '("address_l" IS NULL OR "address_r" IS NULL) AND ("sa4_l" IS NULL OR "sa4_r" IS NULL)',
#      'label_for_charts': '(address is NULL) AND (sa4 is NULL)',
#      'fix_m_probability': False,
#      'fix_u_probability': False,
#      'is_null_level': True},
#     {'sql_condition': 'array_length(list_intersect("address_l", "address_r")) >= 1',
#      'label_for_charts': 'Array intersection size >= 1',
#      'm_probability': 0.7240128110256268,
#      'u_probability': 9.463200931061184e-05,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'array_length(list_intersect("sa4_l", "sa4_r")) >= 1',
#      'label_for_charts': 'Array intersection size >= 1',
#      'm_probability': 0.2759162240638582,
#      'u_probability': 0.050250400044438225,
#      'fix_m_probability': False,
#      'fix_u_probability': False},
#     {'sql_condition': 'ELSE',
#      'label_for_charts': 'All other comparisons',
#      'm_probability': 7.096491051501914e-05,
#      'u_probability': 0.9496549679462511,
#      'fix_m_probability': False,
#      'fix_u_probability': False}],
#    'comparison_description': 'CustomComparison'}]}
